# %% [markdown]
# <a href="https://colab.research.google.com/github/lul-yeah/Probabilidad-y-estadistica/blob/main/Unidad%202/probabilidad_U2_Programa3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Unidad 2
#
# ## practica 3: ejercicios de practica
#
#
# ### facilitador :dr jose gabriel rodriguez rivas
#
# ### alumno : Josue hernadez castro

# %%
import math as mt # Para utilizar factorial
from itertools import permutations # Para utilizar permutaciones
from itertools import product
import numpy as np

# %%
nombres = ["Lucas", "Sofía", "Mateo", "Valentina", "Diego", "Camila", "Javier", "Isabella", "Alejandro", "Mariana"]
n=len(nombres)
r= 4

Pr = mt.factorial(n) / mt.factorial(n-r)

print("el numero de permutaciones es ", Pr , " sin repeticion del total de ", n , " nombres ", "en grupos de ", r ," en ", r)

print("aqui las permutaciones")
permutaciones_list = list(permutations(nombres, r))

#imprime las permutaciones
for permutacion in permutaciones_list:
    print(permutacion)
# Out:
# el numero de permutaciones es  5040.0  sin repeticion del total de  10  nombres  en grupos de  4  en  4
# aqui las permutaciones
# ('Lucas', 'Sofía', 'Mateo', 'Valentina')
# ('Lucas', 'Sofía', 'Mateo', 'Diego')
# ('Lucas', 'Sofía', 'Mateo', 'Camila')
# ('Lucas', 'Sofía', 'Mateo', 'Javier')
# ('Lucas', 'Sofía', 'Mateo', 'Isabella')
# ('Lucas', 'Sofía', 'Mateo', 'Alejandro')
# ('Lucas', 'Sofía', 'Mateo', 'Mariana')
# ('Lucas', 'Sofía', 'Valentina', 'Mateo')
# ('Lucas', 'Sofía', 'Valentina', 'Diego')
# ('Lucas', 'Sofía', 'Valentina', 'Camila')
# ('Lucas', 'Sofía', 'Valentina', 'Javier')
# ('Lucas', 'Sofía', 'Valentina', 'Isabella')
# ('Lucas', 'Sofía', 'Valentina', 'Alejandro')
# ('Lucas', 'Sofía', 'Valentina', 'Mariana')
# ('Lucas', 'Sofía', 'Diego', 'Mateo')
# ('Lucas', 'Sofía', 'Diego', 'Valentina')
# ('Lucas', 'Sofía', 'Diego', 'Camila')
# ('Lucas', 'Sofía', 'Diego', 'Javier')
# ('Lucas', 'Sofía', 'Diego', 'Isabella')
# ('Lucas', 'Sofía', 'Diego', 'Alejandro')
# ...
