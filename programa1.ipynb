# %% [markdown]
# <a href="https://colab.research.google.com/github/lul-yeah/Probabilidad-y-estadistica/blob/main/programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
print(x)
# Out:
# 10

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x="hola hola"
print(x)
# Out:
# hola hola

# %%
a=4
b=8
if a > b:
  print(a,"a es mayor que b",b)
else:
  print(b,"b es mayor a",a)
# Out:
# 8 b es mayor a 4

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png]()![image.png](data:image/png;base64,...))
# # probabilidad y estadistica
#
# ## unidad 1
#
# ### practica 0.introduccion a python
#
# ### grupo:**2Z**
#
# alumno: josue hernandez castro
#
# docente: jose gabriel rodriguez rivas

# %%
for i in range(10):
  print(i)
  print("hola",i)
  print("fuera del for")
# Out:
# 0
# hola 0
# fuera del for
# 1
# hola 1
# fuera del for
# 2
# hola 2
# fuera del for
# 3
# hola 3
# fuera del for
# 4
# hola 4
# fuera del for
# 5
# hola 5
# fuera del for
# 6
# hola 6
# fuera del for
# 7
# hola 7
# fuera del for
# 8
# hola 8
# fuera del for
# 9
# hola 9
# fuera del for
